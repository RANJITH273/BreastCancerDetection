# %% [markdown]
# # Breast Cancer Prediction

# %% [markdown]
# Name : Ranjith B S
#
# Project Name : Breast Cancer Prediction
#
# Date : 28/10/2023

# %% [markdown]
# # Problem Statement :
# The objective of this project is to create a predictive model that can accurately classify breast
# cancer cases as benign or malignant based on a set of relevant features. By leveraging
# historical data and applying machine learning techniques, we aim to develop a reliable tool for
# assisting medical professionals in diagnosing breast cancer.

# %% [markdown]
# # Solution Approach :
# 1. Data Collection: Gather a dataset that contains relevant features and labels for breast cancer cases. This dataset should include information about patients and the characteristics of their tumors. Common sources for such data include the UCI Machine Learning Repository or medical institutions that provide anonymized patient data.
#
# 2. Data Preprocessing: Prepare the data for machine learning by cleaning and transforming it. This involves handling missing values, encoding categorical variables, and scaling or normalizing numerical features. Ensure that the data is in a format suitable for training and testing a machine learning model.
#
# 3. Exploratory Data Analysis (EDA): Perform EDA to understand the data and its characteristics. Explore the relationships between features and the target variable (benign or malignant). Visualization can be a valuable tool for gaining insights from the data.
#
# 4. Feature Selection: Determine which features are most relevant for classification. You can use techniques like feature importance, correlation analysis, or domain knowledge to select the most informative features.
#
# 5. Splitting the Data: Divide the dataset into a training set and a testing set. The training set will be used to train the machine learning model, while the testing set will be used to evaluate its performance.
#
# 6. Model Selection: Choose an appropriate machine learning algorithm for binary classification. Common choices for this task include logistic regression, decision trees, random forests, support vector machines (SVM), and neural networks. Experiment with different models to find the one that performs best for your dataset.This project we use more model selection for best accuracy in this data set
#
# 7. Model Training: Train the selected model on the training data. You may need to fine-tune hyperparameters to optimize the model's performance.
#
# 8. Model Evaluation: Evaluate the model's performance on the testing data using appropriate metrics. Common evaluation metrics for binary classification include accuracy, precision, recall, F1 score, and ROC-AUC.

# %% [markdown]
# # About Dataset :
#
# 1. Dataset is avaliable in Kaggle : https://www.kaggle.com/datasets/nancyalaswad90/breast-cancer-dataset/data
#
# # What is Breast Cancer ?
#
# 1. Breast cancer is the most common cancer amongst women in the world. Breast cancer caused 685 000 deaths globally in 2020. It starts when cells in the breast begin to grow out of control. These cells usually form tumors that can be seen via X-ray or felt as lumps in the breast area.
#
# 2. Approximately 0.5–1% of breast cancers occur in men
#
# Reference : https://www.who.int/news-room/fact-sheets/detail/breast-cancer

# %% [markdown]
# # Dataset and Cancer knowledge :
#
# 1. Fine needle aspiration a type of biopsy procedure. In fine needle aspiration, a thin needle is
# inserted into an area of abnormal-appearing tissue or body fluid. As with other types of
# biopsies, the sample collected during fine needle aspiration can help make a diagnosis or rule
# out conditions such as cancer.
#
# 2. Using this process to find the dataset features like radius mean ,texture mean ,area mean etc..
#
# 3. Using this data we find the tumor wheather tumor is Benign or Malignant tumor
#
# 4. Bengin tumor is non cancerous tumor
#
# 5. Malignant tumor is cancerous tumor
#
# 6. We want to find the tumor using features

# %% [markdown]
# # Let's Start code

# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import jaccard_score
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# # Read Dataset

# %%
dataset = pd.read_csv("D:\CodersCaves_Inten\Git\CVIP-DataScience\Phase_1_Project\BreastCancerPrediction\data.csv") #read the csv file using pandas

# %%
dataset #seeing dataset
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0    ...        25.380          17.33           184.60      2019.0
# 1    ...        24.990          23.41           158.80      1956.0
# 2    ...        23.570          25.53           152.50      1709.0
# 3    ...        14.910          26.50            98.87       567.7
# 4    ...        22.540          16.67           152.20      1575.0
# ..   ...           ...            ...              ...         ...
# 564  ...        25.450          26.40           166.10      2027.0
# 565  ...        23.690          38.25           155.00      1731.0
# 566  ...        18.980          34.12           126.70      1124.0
# 567  ...        25.740          39.42           184.60      1821.0
# 568  ...         9.456          30.37            59.16       268.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      concave_points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %% [markdown]
# # EDA

# %%
dataset.columns #dataset columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave_points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
dataset.shape #dataset shape (rows,columns)
# Out:
# (569, 32)

# %%
dataset.info #dataset information
# Out:
# <bound method DataFrame.info of            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0    ...        25.380          17.33           184.60      2019.0
# 1    ...        24.990          23.41           158.80      1956.0
# 2    ...        23.570          25.53           152.50      1709.0
# 3    ...        14.910          26.50            98.87       567.7
# 4    ...        22.540          16.67           152.20      1575.0
# ..   ...           ...            ...              ...         ...
# 564  ...        25.450          26.40           166.10      2027.0
# 565  ...        23.690          38.25           155.00      1731.0
# 566  ...        18.980          34.12           126.70      1124.0
# 567  ...        25.740          39.42           184.60      1821.0
# 568  ...         9.456          30.37            59.16       268.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      concave_points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 32 columns]>

# %%
dataset.dtypes #dataset feauture datatypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave_points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave_points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# concavity_worst            float64
# concave_points_worst       float64
# symmetry_worst             float64
# fractal_dimension_worst    float64
# dtype: object

# %%
dataset.isnull().sum() #check wheather any NaN value in dataset
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave_points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave_points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave_points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
dataset["diagnosis"].unique() #check the feature for unique value in the features
# Out:
# array(['M', 'B'], dtype=object)

# %%
dataset["diagnosis"].value_counts() #check the count on features
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
#Data Visualization

value_count=dataset["diagnosis"].value_counts()  #bar chart for visualization of Types of cancer
plt.figure(figsize=(16,9))
value_count.plot(kind="bar",color=["green","red"])
plt.title("Cancer Types")
plt.xlabel("Types of Cancer")
plt.ylabel("Counts")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(16,9))
value_count.plot(kind="pie",colors=["green","red"]) #pie chart for Types of cancer
plt.show()
B,M= value_count
print(f"Number of Benign : {B}")
print(f"Number of Benign : {M}")
# Out:
# Number of Benign : 357
# Number of Benign : 212

# %%
sns.pairplot(dataset.iloc[:,0:6],hue="diagnosis")  #pair plot for check the output feature with other feature for understanding of relation or patten in dataset

# %%
dataset.iloc[:,0:6] #just view the 1st 6 columns for above verification
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# [569 rows x 6 columns]

# %%
sns.lmplot(x="radius_mean",y="texture_mean",data=dataset,hue="diagnosis") # lmplot chart

# %%
dataset['diagnosis']=dataset['diagnosis'].replace(['M', 'B'],[1,0]) #catergical to numerical

# %%
dataset["diagnosis"] #just verfication
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
sns.boxplot(dataset["concave_points_worst"]) #check outliers
plt.show()

# %% [markdown]
# # Feature Selection

# %%
cm=dataset.corr().abs()
cm.style.background_gradient(cmap="coolwarm")  #check correlation for feature selection
# Out:
# <style type="text/css">
# #T_359fa_row0_col0, #T_359fa_row1_col1, #T_359fa_row2_col2, #T_359fa_row2_col4, #T_359fa_row3_col3, #T_359fa_row4_col2, #T_359fa_row4_col4, #T_359fa_row5_col5, #T_359fa_row6_col6, #T_359fa_row7_col7, #T_359fa_row8_col8, #T_359fa_row9_col9, #T_359fa_row10_col10, #T_359fa_row11_col11, #T_359fa_row12_col12, #T_359fa_row13_col13, #T_359fa_row14_col14, #T_359fa_row15_col15, #T_359fa_row16_col16, #T_359fa_row17_col17, #T_359fa_row18_col18, #T_359fa_row19_col19, #T_359fa_row20_col20, #T_359fa_row21_col21, #T_359fa_row22_col22, #T_359fa_row23_col23, #T_359fa_row24_col24, #T_359fa_row25_col25, #T_359fa_row26_col26, #T_359fa_row27_col27, #T_359fa_row28_col28, #T_359fa_row29_col29, #T_359fa_row30_col30, #T_359fa_row31_col31 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_359fa_row0_col1, #T_359fa_row6_col23, #T_359fa_row15_col30, #T_359fa_row17_col0, #T_359fa_row29_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_359fa_row0_col2, #T_359fa_row0_col4, #T_359fa_row3_col26, #T_359fa_row5_col20, #T_359fa_row8_col13, #T_359fa_row11_col3, #T_359fa_row14_col30, #T_359fa_row15_col16, #T_359fa_row20_col5, #T_359fa_row21_col30, #T_359fa_row23_col10, #T_359fa_row23_col16, #T_359fa_row26_col13, #T_359fa_row30_col19 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_359fa_row0_col3, #T_359fa_row5_col0, #T_359fa_row13_col15, #T_359fa_row16_col0, #T_359fa_row18_col23, #T_359fa_row20_col22, #T_359fa_row24_col13, #T_359fa_row26_col14, #T_359fa_row29_col16, #T_359fa_row30_col12, #T_359fa_row31_col16 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_359fa_row0_
{
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_359fa_row1_col3, #T_359fa_row2_col27, #T_359fa_row3_col1, #T_359fa_row10_col29, #T_359fa_row26_col10, #T_359fa_row30_col1 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_359fa_row1_col4, #T_359fa_row4_col1, #T_359fa_row4_col15, #T_359fa_row17_col7, #T_359fa_row25_col29, #T_359fa_row27_col8, #T_359fa_row29_col25 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_359fa_row1_col5, #T_359fa_row5_col1, #T_359fa_row24_col14 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_359fa_row1_col6, #T_359fa_row22_col3 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_359fa_row1_col7, #T_359fa_row7_col1, #T_359fa_row15_col8, #T_359fa_row27_col30 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_359fa_row1_col8, #T_359fa_row4_col14, #T_359fa_row15_col9 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_359fa_row1_col9, #T_359fa_row29_col4 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_359fa_row1_col10, #T_359fa_row16_col17, #T_359fa_row27_col14 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_359fa_row1_col11, #T_359fa_row6_col0, #T_359fa_row9_col13, #T_359fa_row15_col31, #T_359fa_row20_col28 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_359fa_row1_col12, #T_359fa_row26_col27, #T_359fa_row29_col19 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_359fa_row1_col14, #T_359fa_row19_col14, #T_359fa_row19_col28, #T_359fa_row22_col7, #T_359fa_row29_col14, #T_359fa_row30_col31 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_359fa_row1_col15, #T_359fa_row14_col29, #T_359fa_row29_col26 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_359fa_row1_col17, #T_359fa_row3_col8, #T_359fa_row6_col14, #T_359fa_row20_col18, #T_359fa_row30_col24 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_359fa_row1_col18, #T_359fa_row10_col15, #T_359fa_row12_col13, #T_359fa_row17_col5, #T_359fa_row19_col26, #T_359fa_row22_col26, #T_359fa_row22_col30 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_359fa_row1_col19, #T_359fa_row3_col24, #T_359fa_row4_col19, #T_359fa_row17_col12, #T_359fa_row22_col23, #T_359fa_row23_col27, #T_359fa_row27_col23, #T_359fa_row29_col23 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_359fa_row1_col21, #T_359fa_row2_col0, #T_359fa_row3_col11, #T_359fa_row4_col20, #T_359fa_row13_col22, #T_359fa_row20_col4, #T_359fa_row20_col9, #T_359fa_row20_col23, #T_359fa_row20_col31, #T_359fa_row25_col13, #T_359fa_row25_col31 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_359fa_row1_col22, #T_359fa_row11_col31, #T_359fa_row31_col11 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_359fa_row1_col23, #T_359fa_row4_col27, #T_359fa_row15_col7, #T_359fa_row23_col1,

# %%
plt.subplots(figsize=(20,20)) #this also correlation but shown in heatmap
sns.heatmap(dataset.corr(),annot=True,fmt=".2f")
# Out:
# <Axes: >

# %%
dataset.corrwith(dataset["diagnosis"]).abs().sort_values() #correlation in sort for feature selection
# Out:
# symmetry_se                0.006522
# texture_se                 0.008303
# fractal_dimension_mean     0.012838
# id                         0.039769
# smoothness_se              0.067016
# fractal_dimension_se       0.077972
# concavity_se               0.253730
# compactness_se             0.292999
# fractal_dimension_worst    0.323872
# symmetry_mean              0.330499
# smoothness_mean            0.358560
# concave_points_se          0.408042
# texture_mean               0.415185
# symmetry_worst             0.416294
# smoothness_worst           0.421465
# texture_worst              0.456903
# area_se                    0.548236
# perimeter_se               0.556141
# radius_se                  0.567134
# compactness_worst          0.590998
# compactness_mean           0.596534
# concavity_worst            0.659610
# concavity_mean             0.696360
# area_mean                  0.708984
# radius_mean                0.730029
# area_worst                 0.733825
# perimeter_mean             0.742636
# radius_worst               0.776454
# concave_points_mean        0.776614
# perimeter_worst            0.782914
# concave_points_worst       0.793566
# diagnosis                  1.000000
# dtype: float64

# %%
remove_cols=["symmetry_se","texture_se","fractal_dimension_mean","id","smoothness_se","fractal_dimension_se"]  #remove low correlation featues
hig_corr=dataset.drop(remove_cols,axis=1)
hig_corr.shape #shape of new dataset
# Out:
# (569, 26)

# %%
x=hig_corr.drop("diagnosis",axis=1) # remove output features
x.shape #shape of new dataset
# Out:
# (569, 25)

# %%
y=dataset["diagnosis"] #output or target feature
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %% [markdown]
# # Scaling or normalizing numerical features

# %%
scaler= StandardScaler() #scaling for better accuaracy
x=scaler.fit_transform(x)

# %%
x #after scaling dataset are convet dataframe to array
# Out:
# array([[ 1.09706398, -2.07333501,  1.26993369, ...,  2.29607613,
#          2.75062224,  1.93701461],
#        [ 1.82982061, -0.35363241,  1.68595471, ...,  1.0870843 ,
#         -0.24388967,  0.28118999],
#        [ 1.57988811,  0.45618695,  1.56650313, ...,  1.95500035,
#          1.152255  ,  0.20139121],
#        ...,
#        [ 0.70228425,  2.0455738 ,  0.67267578, ...,  0.41406869,
#         -1.10454895, -0.31840916],
#        [ 1.83834103,  2.33645719,  1.98252415, ...,  2.28998549,
#          1.91908301,  2.21963528],
#        [-1.80840125,  1.22179204, -1.81438851, ..., -1.74506282,
#         -0.04813821, -0.75120669]])

# %% [markdown]
# # Split train and test data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=12) #split the train and test data

# %% [markdown]
# # Model selection

# %%
# kNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5,n_jobs=-1)

knn.fit(x_train,y_train)

y_predKnn=knn.predict(x_test)

# %% [markdown]
# # Cross Validation
# This is an important step of evaluation of our model, in fact we can find how our models can perform on new data. We will use a k-fold cross validation to detect overfitting, ie, failing to generalize a pattern.

# %%
 #crossvalidation
scoring = ['accuracy', 'precision_macro', 'recall_macro' , 'f1_weighted', 'roc_auc']
sKnn = cross_validate(estimator=knn,X= x, y=y, scoring=scoring, cv=20)

knn_fit_time = sKnn['fit_time'].mean()
knn_score_time = sKnn['score_time'].mean()
knn_accuracy = sKnn['test_accuracy'].mean()
knn_precision = sKnn['test_precision_macro'].mean()
knn_recall = sKnn['test_recall_macro'].mean()
knn_f1 = sKnn['test_f1_weighted'].mean()
knn_roc = sKnn['test_roc_auc'].mean()

# %%
y_predKnn.shape #just for verification
# Out:
# (114,)

# %%
x_test.shape  #just for verification
# Out:
# (114, 25)

# %%
accKnn=accuracy_score(y_test,y_predKnn) #KNC accuracy
accKnn
# Out:
# 0.956140350877193

# %%
jaccard_score(y_test,y_predKnn) #Jaccard score
# Out:
# 0.8958333333333334

# %% [markdown]
# # Model Evaluation

# %%
#confusion matrix
cm=confusion_matrix(y_test,y_predKnn)
sns.heatmap(pd.DataFrame(cm),fmt="g",annot=True)
plt.title("Confusion Matrixs")
plt.ylabel("Actual Label")
plt.xlabel("Predicted Label")
plt.show()

# %%
pd.DataFrame(y_predKnn).value_counts() #just for verification
# Out:
# 0    71
# 1    43
# Name: count, dtype: int64

# %%
y_test.value_counts() #just for verification
# Out:
# diagnosis
# 0    66
# 1    48
# Name: count, dtype: int64

# %% [markdown]
# # Result

# %%
print(f"knn_fit_time:{knn_fit_time}","\n") #After applying cross validate
print(f"knn_score_time :{knn_score_time}","\n")
print(f"knn_accuracy:{knn_accuracy}","\n")
print(f"knn_precision:{knn_precision}","\n")
print(f"knn_recall:{knn_recall}","\n")
print(f"knn_f1:{knn_f1}","\n")
print(f"knn_roc:{knn_roc}","\n")
print("With the help of cross-validation, the model worked more accurately")
# Out:
# knn_fit_time:0.0014728665351867675
#
# knn_score_time :0.06531935930252075
#
# knn_accuracy:0.9701354679802956
#
# knn_precision:0.9739219651177855
#
# knn_recall:0.963989898989899
#
# knn_f1:0.9698348221274916
#
# knn_roc:0.9833184789067143
#
# With the help of cross-validation, the model worked more accurately

# %% [markdown]
# # Conclusion
# In conclusion, the K-Nearest Neighbors (KNN) model and using cross validation offers a accuracy , precision_macro, recall_macro , f1_weighted, roc_auc for classifying breast cancer cases. Further refinements and additional data may be considered to enhance the model's predictive capabilities for assisting medical professionals in diagnosing breast cancer.
